# %%
from salah_at_35k_calculator import salah_calculator

# %%
salah_calculator(flightnumber = 'pk797',
                 departure_time = "3:30:00 PM",
                 prayer_method = "Jafari",
                 date = (2025, 8, 30),
                 flight_early = False,
                 debug = True, 
                 datalog_index = -1)
# Out:
# Flight data extracted!
# {'schedule': [{'label': 'asr',
#    'index': 0,
#    'time_24h': 15.5,
#    'time_12h': '03:30 PM'},
#   {'label': 'fajr', 'index': '—', 'time_24h': None, 'time_12h': '—'},
#   {'label': 'sunrise', 'index': '—', 'time_24h': None, 'time_12h': '—'},
#   {'label': 'dhuhr', 'index': '—', 'time_24h': None, 'time_12h': '—'},
#   {'label': 'maghrib', 'index': '—', 'time_24h': None, 'time_12h': '—'},
#   {'label': 'isha', 'index': '—', 'time_24h': None, 'time_12h': '—'}],
#  'qibla_figs': [Figure({
#       'data': [{'line': {'color': 'black', 'width': 2},
#                 'mode': 'lines',
#                 'name': 'Plane Outline',
#                 'type': 'scatter',
#                 'x': [0.0, 0.2, 0.2, 0.6, 0.6, 0.2, 0.2, 0.5, 0.5, 0.2, 0.2, -0.2,
#                       -0.2, -0.5, -0.5, -0.2, -0.2, -0.6, -0.6, -0.2, -0.2, 0.0],
#                 'y': [1.0, 0.6, 0.3, 0.2, -0.2, -0.3, -0.6, -0.6, -0.8, -0.8, -0.6,
#                       -0.6, -0.8, -0.8, -0.6, -0.6, -0.3, -0.2, 0.2, 0.3, 0.6, 1.0]},
#                {'mode': 'text',
#                 'showlegend': False,
#                 'text': [-97°],
#                 'textfont': {'color': 'red', 'size': 14},
#                 'textposition': 'top center',
#                 'type': 'scatter',
#                 'x': [-0.7910015217789796],
#                 'y': [0.06614939734260997]}],
#       'layout': {'annotations': [{'arrowcolor': 'red',
#                                   'arrowhead': 3,
#                                   'arrowsize': 1.5,
#                                   'arrowwidth': 2,
#                                   'ax': 0,
#                                   'axref': 'x',
#                                   'ay': 0,
#                                   'ayref': 'y',
#                                   'showarrow': True,
#                                   'x': -0.9910015217789797,
#                                   'xref': 'x',
#                                   'y': -0.13385060265739004,
#                                   'yref': 'y'}],
#                  'height': 600,
#                  'showlegend': False,
#                  'template': '...',
#                  'title': {'text': 'Qiblah for: asr'},
#                  'width': 600,
#                  'xaxis': {'scaleanchor': 'y', 'scaleratio': 1, 'visible': False},
#                  'yaxis': {'visible': False}}
#   })],
#  'debug_fig': <Figure size 1000x1000 with 7 Axes>}
